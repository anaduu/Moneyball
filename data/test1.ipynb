# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from numpy import mean
from numpy import std
from scipy.stats import shapiro
from scipy.stats import normaltest
import numpy as np
import seaborn as sns

# %%
DATA_LOCATION = "main_players.csv"
FIRST_ATTRIBUTE = "BallControl"
SECOND_ATTRIBUTE = "Overall"

datas = pd.read_csv(DATA_LOCATION)
data1 = datas[[FIRST_ATTRIBUTE, SECOND_ATTRIBUTE]]

sns.set(style="ticks")

rs = np.random.RandomState(11)
x = datas[FIRST_ATTRIBUTE]
y = datas[SECOND_ATTRIBUTE]


sns.jointplot(x, y, kind="hex", color="#4CB391")

# %%
DATA_LOCATION = "main_players.csv"
FIRST_ATTRIBUTE = "Dribbling"
SECOND_ATTRIBUTE = "Overall"

datas = pd.read_csv(DATA_LOCATION)
data1 = datas[[FIRST_ATTRIBUTE, SECOND_ATTRIBUTE]]

sns.set(style="ticks")

rs = np.random.RandomState(11)
x = datas[FIRST_ATTRIBUTE]
y = datas[SECOND_ATTRIBUTE]


sns.jointplot(x, y, kind="hex", color="#4CB391")

# %%
DATA_LOCATION = "main_players.csv"
FIRST_ATTRIBUTE = "BallControl"
SECOND_ATTRIBUTE = "Dribbling"

datas = pd.read_csv(DATA_LOCATION)
data1 = datas[[FIRST_ATTRIBUTE, SECOND_ATTRIBUTE]]

sns.set(style="ticks")

rs = np.random.RandomState(11)
x = datas[FIRST_ATTRIBUTE]
y = datas[SECOND_ATTRIBUTE]


sns.jointplot(x, y, kind="hex", color="#4CB391")

# %%
DATA_LOCATION = "main_players.csv"
FIRST_ATTRIBUTE = "Reactions"
SECOND_ATTRIBUTE = "Overall"

datas = pd.read_csv(DATA_LOCATION)
data1 = datas[[FIRST_ATTRIBUTE, SECOND_ATTRIBUTE]]

sns.set(style="ticks")

#rs = np.random.RandomState(1100)
x = datas[FIRST_ATTRIBUTE]
y = datas[SECOND_ATTRIBUTE]
tips2 = pd.read_csv('players.csv')
data = sns.load_dataset("players.csv")



sns.jointplot(x, y, kind="hex", color="#4CB391")
sns.lmplot(x, y, data="data");
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-25-b0359900275b> in <module>
#      11 x = datas[FIRST_ATTRIBUTE]
#      12 y = datas[SECOND_ATTRIBUTE]
# ---> 13 data = sns.load_dataset("players.csv")
#      14
#      15
#
# /usr/local/lib/python3.6/dist-packages/seaborn/utils.py in load_dataset(name, cache, data_home, **kws)
#     426                                   os.path.basename(full_path))
#     427         if not os.path.exists(cache_path):
# --> 428             urlretrieve(full_path, cache_path)
#     429         full_path = cache_path
#     430
#
# /usr/lib/python3.6/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     246     url_type, path = splittype(url)
#     247
# --> 248     with contextlib.closing(urlopen(url, data)) as fp:
#     249         headers = fp.info()
#     250
#
# ...
