# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-079272ac-0bf0-45a8-892f-a05a62bd26da" name="files[]" multiple disabled />
#      <output id="result-079272ac-0bf0-45a8-892f-a05a62bd26da">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving main_players.csv to main_players.csv

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('end_players.csv')

# %%
df.plot(x='Overall', y='GKDiving', style='o')  
plt.title('Overall vs GKDiving')  
plt.xlabel('Overall')  
plt.ylabel('GKDiving')  
plt.show()

# %%
df.plot(x='Overall', y='Crossing', style='o')  
plt.title('Overall vs Crossing')  
plt.xlabel('Overall')  
plt.ylabel('Crossing')  
plt.show()

# %%
df.plot(x='Overall', y='Finishing', style='o')  
plt.title('Overall vs Finishing')  
plt.xlabel('Overall')  
plt.ylabel('Finishing')  
plt.show()

# %%
df.plot(x='Overall', y='HeadingAccuracy', style='o')  
plt.title('Overall vs HeadingAccuracy')  
plt.xlabel('Overall')  
plt.ylabel('HeadingAccuracy')  
plt.show()

# %%
df.plot(x='Overall', y='ShortPassing', style='o')  
plt.title('Overall vs ShortPassing')  
plt.xlabel('Overall')  
plt.ylabel('ShortPassing')  
plt.show()

# %%
df.plot(x='Overall', y='Volleys', style='o')  
plt.title('Overall vs Volleys')  
plt.xlabel('Overall')  
plt.ylabel('Volleys')  
plt.show()

# %%
df.plot(x='Overall', y='Dribbling', style='o')  
plt.title('Overall vs Dribbling')  
plt.xlabel('Overall')  
plt.ylabel('Dribbling')  
plt.show()

# %%
df.plot(x='Overall', y='Curve', style='o')  
plt.title('Overall vs Curve')  
plt.xlabel('Overall')  
plt.ylabel('Curve')  
plt.show()

# %%
df.plot(x='Overall', y='FKAccuracy', style='o')  
plt.title('Overall vs FKAccuracy')  
plt.xlabel('Overall')  
plt.ylabel('FKAccuracy')  
plt.show()

# %%
df.plot(x='Overall', y='LongPassing', style='o')  
plt.title('Overall vs LongPassing')  
plt.xlabel('Overall')  
plt.ylabel('LongPassing')  
plt.show()

# %%
df.plot(x='Overall', y='BallControl', style='o')  
plt.title('Overall vs BallControl')  
plt.xlabel('Overall')  
plt.ylabel('BallControl')  
plt.show()

# %%
df.plot(x='Overall', y='Acceleration', style='o')  
plt.title('Overall vs Acceleration')  
plt.xlabel('Overall')  
plt.ylabel('Acceleration')  
plt.show()

# %%
df.plot(x='Overall', y='SprintSpeed', style='o')  
plt.title('Overall vs SprintSpeed')  
plt.xlabel('Overall')  
plt.ylabel('SprintSpeed')  
plt.show()

# %%
df.plot(x='Overall', y='Agility', style='o')  
plt.title('Overall vs Agility')  
plt.xlabel('Overall')  
plt.ylabel('Agility')  
plt.show()

# %%
df.plot(x='Overall', y='Reactions', style='o')  
plt.title('Overall vs Reactions')  
plt.xlabel('Overall')  
plt.ylabel('Reactions')  
plt.show()

# %%
df.plot(x='Overall', y='Balance', style='o')  
plt.title('Overall vs Balance')  
plt.xlabel('Overall')  
plt.ylabel('Balance')  
plt.show()

# %%
df.plot(x='Overall', y='ShotPower', style='o')  
plt.title('Overall vs GShotPower')  
plt.xlabel('Overall')  
plt.ylabel('ShotPower')  
plt.show()

# %%
df.plot(x='Overall', y='Jumping', style='o')  
plt.title('Overall vs Jumping')  
plt.xlabel('Overall')  
plt.ylabel('Jumping')  
plt.show()

# %%
df.plot(x='Overall', y='Stamina', style='o')  
plt.title('Overall vs Stamina')  
plt.xlabel('Overall')  
plt.ylabel('Stamina')  
plt.show()

# %%
df.plot(x='Overall', y='Strength', style='o')  
plt.title('Overall vs Strength')  
plt.xlabel('Overall')  
plt.ylabel('Strength')  
plt.show()

# %%
df.plot(x='Overall', y='LongShots', style='o')  
plt.title('Overall vs LongShots')  
plt.xlabel('Overall')  
plt.ylabel('LongShots')  
plt.show()

# %%
df.plot(x='Overall', y='Aggression', style='o')  
plt.title('Overall vs Aggression')  
plt.xlabel('Overall')  
plt.ylabel('Aggression')  
plt.show()

# %%
df.plot(x='Overall', y='Interceptions', style='o')  
plt.title('Overall vs Interceptions')  
plt.xlabel('Overall')  
plt.ylabel('Interceptions')  
plt.show()

# %%
df.plot(x='Overall', y='Positioning', style='o')  
plt.title('Overall vs Positioning')  
plt.xlabel('Overall')  
plt.ylabel('Positioning')  
plt.show()

# %%
df.plot(x='Overall', y='Vision', style='o')  
plt.title('Overall vs Vision')  
plt.xlabel('Overall')  
plt.ylabel('Vision')  
plt.show()

# %%
df.plot(x='Overall', y='Penalties', style='o')  
plt.title('Overall vs Penalties')  
plt.xlabel('Overall')  
plt.ylabel('Penalties')  
plt.show()

# %%
df.plot(x='Overall', y='Composure', style='o')  
plt.title('Overall vs Composure')  
plt.xlabel('Overall')  
plt.ylabel('Composure')  
plt.show()

# %%
df.plot(x='Overall', y='Marking', style='o')  
plt.title('Overall vs Marking')  
plt.xlabel('Overall')  
plt.ylabel('Marking')  
plt.show()

# %%
df.plot(x='Overall', y='StandingTackle', style='o')  
plt.title('Overall vs StandingTackle')  
plt.xlabel('Overall')  
plt.ylabel('StandingTackle')  
plt.show()

# %%
df.plot(x='Overall', y='SlidingTackle', style='o')  
plt.title('Overall vs SlidingTackle')  
plt.xlabel('Overall')  
plt.ylabel('SlidingTackle')  
plt.show()

# %%
df.plot(x='Overall', y='GKDiving', style='o')  
plt.title('Overall vs GKDiving')  
plt.xlabel('Overall')  
plt.ylabel('GKDiving')  
plt.show()

# %%
df.plot(x='Overall', y='GKHandling', style='o')  
plt.title('Overall vs GKHandling')  
plt.xlabel('Overall')  
plt.ylabel('GKHandling')  
plt.show()

# %%
df.plot(x='Overall', y='GKKicking', style='o')  
plt.title('Overall vs GKKicking')  
plt.xlabel('Overall')  
plt.ylabel('GKKicking')  
plt.show()

# %%
df.plot(x='Overall', y='GKPositioning', style='o')  
plt.title('Overall vs GKPositioning')  
plt.xlabel('Overall')  
plt.ylabel('GKPositioning')  
plt.show()

# %%
df.plot(x='Overall', y='GKReflexes', style='o')  
plt.title('Overall vs GKReflexes')  
plt.xlabel('Overall')  
plt.ylabel('GKReflexes')  
plt.show()
